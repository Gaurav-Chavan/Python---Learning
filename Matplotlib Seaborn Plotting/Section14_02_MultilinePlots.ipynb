# %% [markdown]
# ## Multiline Plots

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10)
plt.plot(x, x**2)
plt.plot(x, x**3)
plt.plot(x, x*2)
plt.plot(x, 2**x)
plt.show()

# %%
plt.plot(x, x**2, x, x**3, x, x*2, x, 2**x)
plt.show()

# %%
x = np.array([[1, 2, 6, 3], [4, 5, 3, 2]])
plt.plot(x)
plt.show()

# %%
data = np.random.randn(2, 10)
print(data)
plt.plot(data[0], data[1])
plt.show()
# Out:
# [[-0.00948122  0.17133791  0.72973554  0.11308914 -0.76490625 -0.37204513
#    0.92652342 -0.4939871   0.35027443 -3.61965484]
#  [ 0.32355513  1.26298208  0.14879    -0.46932156  0.69397036  0.83047262
#   -0.41306903  1.83816105 -1.1110951   1.2071825 ]]
